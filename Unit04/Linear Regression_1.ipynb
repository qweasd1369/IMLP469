# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [1.48883545 1.97709309 1.2360096  2.14156532 0.23621665 0.68691523
#  1.51493669 1.83176191 2.7921185  1.41545407 2.40865823 2.09178845
#  1.99761266 2.50779402 2.20649504 2.92184682 2.73324213 3.64359747
#  2.2729628  4.35001318 2.94534343 3.50427016 3.03753432 3.78687153
#  3.69031015 4.5511518  3.44305844 3.91734382 2.58268347 3.50218767
#  5.36904893 4.25526359 3.64519822 3.88683293 4.97806916 5.67004788
#  5.32703557 5.65084039 5.35784416 5.47213847 5.62550008 6.12563865
#  6.9495659  6.45680387 6.20170961 6.45406472 6.48964857 6.77164295
#  6.06789276 5.85899222]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
from sklearn import set_config
set_config(display='text')

regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.9542611  1.07043775 1.1866144  1.30279105 1.4189677  1.53514435
#  1.651321   1.76749765 1.8836743  1.99985095 2.1160276  2.23220424
#  2.34838089 2.46455754 2.58073419 2.69691084 2.81308749 2.92926414
#  3.04544079 3.16161744 3.27779409 3.39397074 3.51014739 3.62632404
#  3.74250069 3.85867734 3.97485399 4.09103064 4.20720729 4.32338394
#  4.43956059 4.55573724 4.67191389 4.78809054 4.90426719 5.02044384
#  5.13662049 5.25279713 5.36897378 5.48515043 5.60132708 5.71750373
#  5.83368038 5.94985703 6.06603368 6.18221033 6.29838698 6.41456363
#  6.53074028 6.64691693]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3750522144944146

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.13853117])

# %%
b=regr.intercept_ #截距
b
# Out:
# np.float64(0.9542610992270624)

# %%
Y
# Out:
# array([0.9542611 , 1.07043775, 1.1866144 , 1.30279105, 1.4189677 ,
#        1.53514435, 1.651321  , 1.76749765, 1.8836743 , 1.99985095,
#        2.1160276 , 2.23220424, 2.34838089, 2.46455754, 2.58073419,
#        2.69691084, 2.81308749, 2.92926414, 3.04544079, 3.16161744,
#        3.27779409, 3.39397074, 3.51014739, 3.62632404, 3.74250069,
#        3.85867734, 3.97485399, 4.09103064, 4.20720729, 4.32338394,
#        4.43956059, 4.55573724, 4.67191389, 4.78809054, 4.90426719,
#        5.02044384, 5.13662049, 5.25279713, 5.36897378, 5.48515043,
#        5.60132708, 5.71750373, 5.83368038, 5.94985703, 6.06603368,
#        6.18221033, 6.29838698, 6.41456363, 6.53074028, 6.64691693])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.3698546])

# %%
y
# Out:
# array([1.48883545, 1.97709309, 1.2360096 , 2.14156532, 0.23621665,
#        0.68691523, 1.51493669, 1.83176191, 2.7921185 , 1.41545407,
#        2.40865823, 2.09178845, 1.99761266, 2.50779402, 2.20649504,
#        2.92184682, 2.73324213, 3.64359747, 2.2729628 , 4.35001318,
#        2.94534343, 3.50427016, 3.03753432, 3.78687153, 3.69031015,
#        4.5511518 , 3.44305844, 3.91734382, 2.58268347, 3.50218767,
#        5.36904893, 4.25526359, 3.64519822, 3.88683293, 4.97806916,
#        5.67004788, 5.32703557, 5.65084039, 5.35784416, 5.47213847,
#        5.62550008, 6.12563865, 6.9495659 , 6.45680387, 6.20170961,
#        6.45406472, 6.48964857, 6.77164295, 6.06789276, 5.85899222])
